# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
no_ball = cv2.imread("table_no_ball.png")
back_ball = cv2.imread("table_back_ball.png")
close_ball = cv2.imread("table_close_ball.png")

# %%
fig, axes = plt.subplots(3, 1)
fig.set_figwidth(15)
fig.set_figheight(30)
axes[0].imshow(no_ball)
axes[1].imshow(back_ball)
axes[2].imshow(close_ball)

# %%
from ball_tracking import Tracker

# %%
tracker = Tracker(2272, (no_ball.shape[1], no_ball.shape[0]), None)

# %%
tracker.track(no_ball)
tracker.track(close_ball)
tracker.track(no_ball)
tracker.track(back_ball)
# Out:
# /home/damian/pingpong/ball_tracking.py:171: RuntimeWarning: divide by zero encountered in scalar divide
#   value = (x / (ax1 / 2))**2 + (y / (ax2 / 2))**2
# /home/damian/pingpong/ball_tracking.py:171: RuntimeWarning: invalid value encountered in scalar divide
#   value = (x / (ax1 / 2))**2 + (y / (ax2 / 2))**2
# (((3215.825439453125, 1109.1502685546875),
#   (39.666988372802734, 89.3056411743164),
#   4.364887237548828),
#  np.float64(0.8652455173880884))

# %%
print(tracker.recorded_distances)
# Out:
# [4.9585348398478, 4.9585348398478, 7.516646749124826]
